# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/train.csv", parse_dates=["date"])
df
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3000883            0
# 3000884            1
# 3000885          148
# 3000886            8
# 3000887            0
#
# [3000888 rows x 6 columns]

# %%
df = df.set_index("date").to_period("D")
df
# Out:
#                  id  store_nbr                      family     sales  \
# date
# 2013-01-01        0          1                  AUTOMOTIVE     0.000
# 2013-01-01        1          1                   BABY CARE     0.000
# 2013-01-01        2          1                      BEAUTY     0.000
# 2013-01-01        3          1                   BEVERAGES     0.000
# 2013-01-01        4          1                       BOOKS     0.000
# ...             ...        ...                         ...       ...
# 2017-08-15  3000883          9                     POULTRY   438.133
# 2017-08-15  3000884          9              PREPARED FOODS   154.553
# 2017-08-15  3000885          9                     PRODUCE  2419.729
# 2017-08-15  3000886          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 2017-08-15  3000887          9                     SEAFOOD    16.000
#
#             onpromotion
# date
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# 2013-01-01            0
# ...                 ...
# 2017-08-15            0
# 2017-08-15            1
# 2017-08-15          148
# 2017-08-15            8
# 2017-08-15            0
#
# [3000888 rows x 5 columns]

# %%
moving_average = df.rolling(
    window = 12,
    center = True,
    min_periods = 6,
).mean()

ax = df.plot(style=".", color="0.5")
moving_average.plot(
    ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False,
);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\users\isaak\desktop\python\storesales\env\lib\site-packages\pandas\core\window\rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas\\_libs\\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'AUTOMOTIVE'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File c:\users\isaak\desktop\python\storesales\env\lib\site-packages\pandas\core\window\rolling.py:489, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     488 try:
# --> 489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
#
# File c:\users\isaak\desktop\python\storesales\env\lib\site-packages\pandas\core\window\rolling.py:373, in BaseWindow._prep_values(self, values)
#     372 except (ValueError, TypeError) as err:
# --> 373     raise TypeError(f"cannot handle this type -> {values.dtype}") from err
#     375 # Convert inf to nan for C funcs
#
# TypeError: cannot handle this type -> object
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 moving_average = df.rolling(
#       2     window = 12,
#       3     center = True,
#       4     min_periods = 6,
#       5 ).mean()
#       7 ax = df.plot(style=".", color="0.5")
#       8 moving_average.plot(
#       9     ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False,
#      10 );
#
# File c:\users\isaak\desktop\python\storesales\env\lib\site-packages\pandas\core\window\rolling.py:2259, in Rolling.mean(self, numeric_only, engine, engine_kwargs)
#    2216 @doc(
#    2217     template_header,
#    2218     create_section_header("Parameters"),
#    (...)
#    2257     engine_kwargs: dict[str, bool] | None = None,
#    2258 ):
# -> 2259     return super().mean(
#    2260         numeric_only=numeric_only,
#    2261         engine=engine,
#    2262         engine_kwargs=engine_kwargs,
#    2263     )
#
# File c:\users\isaak\desktop\python\storesales\env\lib\site-packages\pandas\core\window\rolling.py:1625, in RollingAndExpandingMixin.mean(self, numeric_only, engine, engine_kwargs)
#    1623         return self._numba_apply(sliding_mean, engine_kwargs)
#    1624 window_func = window_aggregations.roll_mean
# -> 1625 return self._apply(window_func, name="mean", numeric_only=numeric_only)
#
# File c:\users\isaak\desktop\python\storesales\env\lib\site-packages\pandas\core\window\rolling.py:619, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     616     return result
#     618 if self.method == "single":
# --> 619     return self._apply_columnwise(homogeneous_func, name, numeric_only)
#     620 else:
#     621     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File c:\users\isaak\desktop\python\storesales\env\lib\site-packages\pandas\core\window\rolling.py:491, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
# --> 491     raise DataError(
#     492         f"Cannot aggregate non-numeric type: {arr.dtype}"
#     493     ) from err
#     494 res = homogeneous_func(arr)
#     495 res_values.append(res)
#
# DataError: Cannot aggregate non-numeric type: object
